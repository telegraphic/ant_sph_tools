# %%
from ant_sph_tools import read_sph, sph_to_farfield
import numpy as np
from scipy.io import loadmat
import pylab as plt

# %%
sph_data = read_sph('dipole_FarField1_299MHz.sph')
mat_data = loadmat('tests/test_FFfromSph.mat')

theta = np.deg2rad(np.arange(0, 91))
phi = np.deg2rad(np.arange(0, 361))

E_th, E_ph, mode_counter = sph_to_farfield(sph_data['Q'], 
                                           sph_data['mmax'], 
                                           sph_data['nmax'], theta, phi)
# Out:
# 4 4 48
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:67: RuntimeWarning: invalid value encountered in divide
#   NPdsm = NP[abs(m), :] / np.sin(theta) * m
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:68: RuntimeWarning: invalid value encountered in divide
#   NPdsabsm = NP[abs(m), :] / np.sin(theta) * abs(m)
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:67: RuntimeWarning: divide by zero encountered in divide
#   NPdsm = NP[abs(m), :] / np.sin(theta) * m
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:67: RuntimeWarning: invalid value encountered in multiply
#   NPdsm = NP[abs(m), :] / np.sin(theta) * m
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:68: RuntimeWarning: divide by zero encountered in divide
#   NPdsabsm = NP[abs(m), :] / np.sin(theta) * abs(m)
# /Users/daniel.price/Data/ska-sph-feko/ant_sph_tools/farfield.py:68: RuntimeWarning: invalid value encountered in multiply
#   NPdsabsm = NP[abs(m), :] / np.sin(theta) * abs(m)

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.imshow(np.abs(E_th), aspect='auto')
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(np.abs(mat_data['E_th']), aspect='auto')
plt.colorbar()

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.imshow(np.abs(E_ph), aspect='auto')
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(np.abs(mat_data['E_ph']), aspect='auto')
plt.colorbar()
